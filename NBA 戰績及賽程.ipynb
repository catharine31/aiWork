# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
# python 裡的excel
import pandas as pd

# %%
#NBA 全聯盟戰績
df_temp = pd.read_html('https://s5.sir.sportradar.com/taiwansportslottery/zht/2/season/68176')
len(df_temp)

# %%
df = df_temp[0]
df

# %%
# NBA 賽程
df_temp = pd.read_html('https://s5.sir.sportradar.com/taiwansportslottery/zht/2/season/68176/fixtures')
len(df_temp)
# Out:
# 1

# %%
df = df_temp[0]
column_name = df.loc[0, :]
df.columns = column_name
df
df.drop(0, inplace=True)
df.dropna(axis=1, how='all', inplace=True)

# %%
df
# Out:
# 0      三月 2020              三月 2020     三月 2020     三月 2020     三月 2020  \
# 1   2020/03/01                  NaN           1           2           3
# 2        08:30  波特蘭拓荒者POR-亞特蘭大老鷹ATL  28:2328:23  28:4028:40  34:4434:44
# 3        08:30  布魯克林籃網布魯克林-邁阿密熱火MIA  27:2427:24  22:3322:33  31:3431:34
# 4        09:00  印第安那溜馬IND-克里夫蘭騎士CLE  30:3130:31  26:2726:27  30:2830:28
# 5        09:00    洛杉磯湖人LAL-曼斐斯灰熊MEM  25:2925:29  21:2921:29  20:2820:28
# ..         ...                  ...         ...         ...         ...
# 95       07:30    紐約尼克NYK-亞特蘭大老鷹ATL  33:2433:24  34:2634:26  29:2829:28
# 96       07:30   夏洛特黃蜂夏洛特黃-邁阿密熱火MIA  22:4022:40  37:1137:11  28:2628:26
# 97       08:00   猶他爵士UTA-奧克拉荷馬雷霆OKC          --          --          --
# 98       08:00    丹佛金塊DEN-達拉斯獨行俠DAL  29:3329:33  21:2421:24  35:2735:27
# 99       10:30  紐奧良鵜鶘紐奧良鵜-沙加緬度國王SAC          --          --          --
#
# 0      三月 2020         三月 2020         三月 2020
# 1            4             正規賽             延長賽
# 2   27:2227:22  117:129117:129              --
# 3   33:2533:25  113:116113:116              --
# 4   27:1827:18  113:104113:104              --
# 5   22:1922:19    88:10588:105              --
# ..         ...             ...             ...
# 95  22:4022:40  118:118118:118  136:131136:131
# 96  22:2122:21    109:98109:98              --
# 97          --             NaN              --
# 98  12:2912:29    97:11397:113              --
# 99          --             NaN              --
#
# [99 rows x 8 columns]

# %%
len(df)
# Out:
# 99

# %%
def getScore(a):
    try:
        b = a.split(':')
        c = ':'.join( [b[0], b[2]])
        return c
    except (AttributeError, IndexError):
        return "--"

# %%
for i in range(1, len(df)):
    for j in range(2, 8):
        newScore = getScore(df.iloc[i, j])
        df.iloc[i, j] = newScore
df
# Out:
# 0      三月 2020              三月 2020 三月 2020 三月 2020 三月 2020 三月 2020  三月 2020  \
# 1   2020/03/01                  NaN       1       2       3       4      正規賽
# 2        08:30  波特蘭拓荒者POR-亞特蘭大老鷹ATL   28:23   28:40   34:44   27:22  117:129
# 3        08:30  布魯克林籃網布魯克林-邁阿密熱火MIA   27:24   22:33   31:34   33:25  113:116
# 4        09:00  印第安那溜馬IND-克里夫蘭騎士CLE   30:31   26:27   30:28   27:18  113:104
# 5        09:00    洛杉磯湖人LAL-曼斐斯灰熊MEM   25:29   21:29   20:28   22:19   88:105
# ..         ...                  ...     ...     ...     ...     ...      ...
# 95       07:30    紐約尼克NYK-亞特蘭大老鷹ATL   33:24   34:26   29:28   22:40  118:118
# 96       07:30   夏洛特黃蜂夏洛特黃-邁阿密熱火MIA   22:40   37:11   28:26   22:21   109:98
# 97       08:00   猶他爵士UTA-奧克拉荷馬雷霆OKC      --      --      --      --       --
# 98       08:00    丹佛金塊DEN-達拉斯獨行俠DAL   29:33   21:24   35:27   12:29   97:113
# 99       10:30  紐奧良鵜鶘紐奧良鵜-沙加緬度國王SAC      --      --      --      --       --
#
# 0   三月 2020
# 1       延長賽
# 2        --
# 3        --
# 4        --
# 5        --
# ..      ...
# 95  136:131
# 96       --
# 97       --
# 98       --
# 99       --
#
# [99 rows x 8 columns]
